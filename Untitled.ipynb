# %%
import pandas as pd
df=pd.read_csv('datarwrapper_scholarship.csv')
df
# Out:
#                                       University name Has description Changed
# 0                   Middle Tennessee State University                     NO
# 1                                Loyola M University                      NO
# 2                                               BGSU                      NO
# 3                                                 UA                      NO
# 4                                   Drake University                      YES
# 5                                    University of SC                     NO
# 6                          Westfield State University                     NO
# 7                                             Depaul                      YES
# 8                   Pennylvania-College-of-Technology                     YES
# 9                                  Indiana University                     NO
# 10                              North Star Collective                     YES
# ...

# %%
df['Has description Changed'].value_counts()
# Out:
# Has description Changed
# YES     18
# NO      16
# YES      3
# Yes      2
# N/A      1
# Name: count, dtype: int64

# %%
# %load_ext rpy2.ipython
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline  
from matplotlib import rcParams
rcParams['figure.figsize'] = (16, 100)

import warnings
from rpy2.rinterface import RRuntimeWarning
warnings.filterwarnings("ignore") # Ignore all warnings
# warnings.filterwarnings("ignore", category=RRuntimeWarning) # Show some warnings

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, HTML

# %%
# %%javascript
# // Disable auto-scrolling
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }
#
# %%R
#
# # My commonly used R imports
#
# require('tidyverse')

# %%
# %%R
# responses <- c(23, 16, 1)
# categories <- c("Removed or changed", "No changes", "N/A")
#
# # Create barplot
# barplot(responses,
#         names.arg = categories,
#         col = "skyblue",
#         main = "Number of universities that have removed or altered scholarships",
#         ylab = "Count",
#         ylim = c(0, max(responses) + 5))

# %%
# %%R
#
# responses <- c(23, 16, 1)
# categories <- c("Yes changes", "No changes", "N/A")
#
# # Create barplot
# barplot(responses,
#         names.arg = categories,
#         col = "skyblue",
#         main = "Scholarship Changes Reported by Universities",
#         xlab = "Type of Scholarship Change",
#         ylab = "Number of Universities",
#         ylim = c(0, max(responses) + 5))

# %%
# %%R
#
#
# # Set up SVG device
# svg("scholarship_changes.svg", width = 6, height = 4)  # you can adjust width/height
#
# # Your plot
# responses <- c(23, 16, 1)
# categories <- c("Yes changes", "No changes", "N/A")
#
# barplot(responses,
#         names.arg = categories,
#         col = "skyblue",
#         main = "Scholarship Changes Reported by Universities",
#         xlab = "Type of Scholarship Change",
#         ylab = "Number of Universities",
#         ylim = c(0, max(responses) + 5))
#
# # Close the device to write the file
# dev.off()
# Out:
# quartz_off_screen
#                 2
